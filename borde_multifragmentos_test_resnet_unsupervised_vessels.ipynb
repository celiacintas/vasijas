# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
import scipy.ndimage as nd
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import skimage.measure as sk
from utils import utils
plt.style.use('ggplot')
from sklearn import metrics

# %%
from torch.autograd import Variable
from torchvision import datasets
from torchvision import transforms as tfs
from torch.utils import data
import torch
import PIL.ImageOps
import skimage
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

# %%
available_device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# #### Load dataset

# %%
transformations = [tfs.RandomAffine(0., scale=(0.5, 1.), fillcolor=0),
                   tfs.Resize((128, 128)),
                   #tfs.Grayscale(1),
                   tfs.Lambda(lambda x: PIL.ImageOps.invert(x))]

imagenet_data = datasets.ImageFolder('data/perfiles_CATA/png_clasificados/',
                                     transform=tfs.Compose(transformations))

data_loader = data.DataLoader(imagenet_data, batch_size=4, shuffle=False)

# %%
print(len(imagenet_data))
# Out:
# 23831

# %%
fig = plt.figure()

for i in range(len(imagenet_data)):
    sample = imagenet_data[i + 10]
    #print(sample)
    ax = plt.subplot(1, 5, i + 1)
    plt.tight_layout()
    plt.imshow(np.asarray(sample[0]), cmap=plt.cm.gray_r)
    ax.set_title('Sample {}'.format(i))
    ax.axis('off')

    if i == 4:
        plt.show()
        break

# %% [markdown]
# #### Process type of vessels for classification

# %%
df = utils.create_df_from_files(path='data/perfiles_CATA/clases/')

# %% [markdown]
# #### Build and train classifier

# %%
imagenet_data = datasets.ImageFolder('data/perfiles_CATA/png_clasificados/',
                                     transform=tfs.Compose([tfs.RandomHorizontalFlip(p=0.7),
                                                           tfs.RandomAffine(0, scale=(0.7, 1.), fillcolor=0),
                                                           tfs.Resize((128, 128)),
                                                           tfs.RandomRotation((0,360)),
                                                           tfs.ToTensor()]))

# %%
splits_len = round(len(imagenet_data.samples)*0.2), round(len(imagenet_data.samples)*0.1), round(len(imagenet_data.samples)*0.7)

# %%
#splits_len = splits_len if np.sum(splits_len) == len(imagenet_data.samples) else splits_len[0]-1, splits_len[1], splits_len[2] +2

# %% [markdown]
# #### Split

# %%
np.sum(splits_len)
# Out:
# 23831

# %%
#All
splits = utils.random_split(imagenet_data, splits_len)
print(splits_len)
# Out:
# (4766, 2383, 16682)

# %%
"""
import pickle
file_pi2 = open('data_pickle/indice_0.pickle', 'rb') 
splits[0].indices = pickle.load(file_pi2)
print(len(splits[0].indices))

file_pi2 = open('data_pickle/indice_1.pickle', 'rb') 
splits[2].indices = pickle.load(file_pi2)
print(len(splits[2].indices))
"""
# Out:
# "\nimport pickle\nfile_pi2 = open('data_pickle/indice_0.pickle', 'rb') \nsplits[0].indices = pickle.load(file_pi2)\nprint(len(splits[0].indices))\n\nfile_pi2 = open('data_pickle/indice_1.pickle', 'rb') \nsplits[2].indices = pickle.load(file_pi2)\nprint(len(splits[2].indices))\n"

# %%
train_loader = data.DataLoader(splits[2], batch_size=32, shuffle=False)
test_loader = data.DataLoader(splits[0], batch_size=32, shuffle=False)

# %%
import torch.optim as optim
from torch import nn
from models.classifierResnet import _C
import visdom
from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import TopKCategoricalAccuracy, Loss
from ignite.handlers import ModelCheckpoint
import torch.nn.functional as F

# %%
C =_C(input_h_w=128)
C = C.to(available_device)
checkpoint = torch.load("models/multifrac_checkpoint_data_resnet/multifrac_cnn_vessels_model_476.pth")
C.load_state_dict(checkpoint)

# %%
y_real_test, X_test = utils.iterations_test_partial(C, test_loader, available_device)
y_real_train, X_train = utils.iterations_test_partial(C, train_loader, available_device)

# %%
X_train, y_real_train = np.array(X_train), np.array(y_real_train)
X_test, y_real_test = np.array(X_test), np.array(y_real_test)

# %%
files_train = np.array(imagenet_data.imgs)[train_loader.dataset.indices][:, 0]
merged_train = pd.DataFrame(np.concatenate(( np.expand_dims(files_train, 1), np.expand_dims(y_real_train, 1)), axis=1))

# %%
files_test = np.array(imagenet_data.imgs)[test_loader.dataset.indices][:, 0]
merged_test = pd.DataFrame(np.concatenate(( np.expand_dims(files_test, 1), np.expand_dims(y_real_test, 1)), axis=1))

# %%
X_train = np.concatenate([X_train, X_test])

# %%
X_train.shape, X_test.shape
# Out:
# ((21448, 512), (4766, 512))

# %%
y_real_train = np.concatenate([y_real_train.reshape(-1, 1), y_real_test.reshape(-1, 1)])

# %%
y_real_train.shape, y_real_test.shape
# Out:
# ((21448, 1), (4766,))

# %%
merged_train = pd.concat([merged_train, merged_test])

# %% [markdown]
# # UMAP

# %%
import umap
plt.rcParams['figure.figsize'] = [9.0*2, 6.0*2]
fit = umap.UMAP(
        n_neighbors=15,
        min_dist=0.1,
        n_components=2,
        metric='euclidean',
        random_state=17
    )
u = fit.fit_transform(X_train);
fig = plt.figure()
#ax = fig.add_subplot(111)
utils.plot_embedding(u[:,[0,1]], merged_train, "", 11)
#ax.scatter(u[:,0], u[:,1], c=c)
plt.gca().set_aspect('equal')
#plt.savefig("result_plot/resNet/unap_resnet.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import make_scorer

# %%
def select_file(img_n):
    replace_string = re.findall("\/*_frac_\w_\w*.png", img_n)
    if len(replace_string)==0:
        replace_string =".png"
    else:
        replace_string = replace_string[0]
    img_select = img_n.replace(replace_string, "")
    return img_select

# %%
X_train.shape, y_real_train.shape, merged_train.shape
# Out:
# ((21448, 512), (21448, 1), (21448, 2))

# %%
df = pd.DataFrame(X_train)

# %%
df["target"] = y_real_train
df["image"] = np.array(merged_train[0])

# %%
df.to_csv("data/result.csv")

# %%
import skimage

# %%
idtest=1100

# %%
X_train.shape
# Out:
# (21448, 512)

# %%
merged_train.shape
# Out:
# (21448, 2)

# %%
plt.imshow(skimage.io.imread(merged_train.iloc[idtest][0], 0))

# %%
import scipy
import re

# %%
img_n = merged_train.iloc[idtest][0]
img_select = select_file(img_n)

# %%
dist = []
for j,i in enumerate(X_train):
    a = scipy.spatial.distance.euclidean(i, X_train[idtest])
    img_n = merged_train.iloc[j][0]
    img_n = select_file(img_n)
    if a == 0 or img_select==img_n:
        dist.append(100000000)
    else:
        dist.append(a)

# %%
merged_train.iloc[np.argmin(dist)]
# Out:
# 0    data/perfiles_CATA/png_clasificados/10/CCNE_6_...
# 1                                                    1
# Name: 3567, dtype: object

# %%
merged_train.iloc[np.argmin(dist)][0]
# Out:
# 'data/perfiles_CATA/png_clasificados/10/CCNE_6_frac_9_full.png'

# %%
merged_train.iloc[idtest]
# Out:
# 0    data/perfiles_CATA/png_clasificados/10/AL_05G_...
# 1                                                    1
# Name: 1100, dtype: object

# %%
merged_train.iloc[idtest][0]
# Out:
# 'data/perfiles_CATA/png_clasificados/10/AL_05G_frac_8_full.png'

# %%
plt.imshow(skimage.io.imread(merged_train.iloc[np.argmin(dist)][0], 0))

# %%
merged_train.iloc[np.argmin(dist)][0], merged_train.iloc[idtest][0]
# Out:
# ('data/perfiles_CATA/png_clasificados/10/CCNE_6_frac_9_full.png',
#  'data/perfiles_CATA/png_clasificados/10/AL_05G_frac_8_full.png')

# %%
imgA = merged_train.iloc[idtest][0]
imgB = merged_train.iloc[np.argmin(dist)][0]

# %%
fig = plt.figure()
ax = fig.add_subplot(121)
ax.imshow(skimage.io.imread(merged_train.iloc[np.argmin(dist)][0], 0), alpha=0.6)
ax = fig.add_subplot(122)
ax.imshow(skimage.io.imread(merged_train.iloc[idtest][0].replace("full", "part"), 0), alpha=0.6)

# %%
imgA
# Out:
# 'data/perfiles_CATA/png_clasificados/10/AL_05G_frac_8_full.png'

# %%
replace_string = re.findall("\/*_frac_\w_\w*.png", imgA)[0]

# %%
fig, ax = plt.subplots()
#ax.imshow(skimage.io.imread(imgB, 0), alpha=0.6)

ax.imshow(skimage.io.imread(imgA.replace("part", "full"), 0 ), alpha=0.6)
ax.imshow(skimage.io.imread(imgA.replace(replace_string, ".png"), 0), alpha=0.3)

# %%
#replace_string = re.findall("\/*_frac_\w_\w*.png", imgB)[0]
replace_string = select_file(imgB)

# %%
replace_string
# Out:
# 'data/perfiles_CATA/png_clasificados/10/CCNE_6'

# %%
fig, ax = plt.subplots()
#ax.imshow(skimage.io.imread(imgB, 0), alpha=0.6)

ax.imshow(skimage.io.imread(imgB.replace("part","full"), 0 ), alpha=0.6)
ax.imshow(skimage.io.imread(replace_string+".png", 0), alpha=0.3)
