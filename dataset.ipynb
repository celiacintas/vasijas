# %%
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
imgs = np.array(glob.glob('imageRealsTest_v9/*.png'))

# %%
imgs = imgs[np.random.randint(0, len(imgs), len(imgs))]

# %%
plt.figure(figsize=(6,8))
for i in range(50):
    plt.subplot(10, 5, i +1)
    plt.imshow(plt.imread(imgs[i]))
    plt.xticks([])
    plt.yticks([])
    plt.axis("off")
    #plt.title('{}'.format(i+1))
plt.savefig('realdatset.png', dpi=300)
